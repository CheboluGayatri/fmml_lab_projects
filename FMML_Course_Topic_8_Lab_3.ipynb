# %% [markdown]
# <a href="https://colab.research.google.com/github/CheboluGayatri/fmml_lab_projects/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 14:07:11--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  79.0MB/s    in 0.9s
#
# 2024-03-31 14:07:12 (79.0 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 39405  1602.07613v2  We present a mathematical and algorithmic sche...    cs
# 32474   1211.1513v2  In this paper, we present a novel algorithm fo...    cs
# 21846   1401.0086v2  We consider forward-backward greedy algorithms...  stat
# 35372  cs/0502088v1  In [Hitzler and Wendt 2002, 2005], a new metho...    cs
# 2618   1611.05763v3  In recent years deep reinforcement learning (R...    cs
# ...             ...                                                ...   ...
# 14053  1707.01812v1  The performance of the meta-heuristic algorith...    cs
# 22957  1711.08536v1  Modern machine learning systems such as image ...  stat
# 22533  1610.09600v4  Exploiting the fact that most arrival processe...  stat
# 6836   1706.06136v1  Clustering is one of the most universal approa...  stat
# 5979    1402.0914v1  Networks play a central role in modern data an...  stat
#
#                                                    title  year  \
# 39405              Learning Shapes by Convex Composition  2016
# 32474                                 K-Plane Regression  2012
# 21846  Forward-Backward Greedy Algorithms for General...  2013
# 35372  Towards a Systematic Account of Different Sema...  2005
# 2618                     Learning to reinforcement learn  2016
# ...                                                  ...   ...
# 14053  ACO for Continuous Function Optimization: A Pe...  2017
# 22957  No Classification without Representation: Asse...  2017
# 22533  Super-resolution estimation of cyclic arrival ...  2016
# 6836   On comparing clusterings: an element-centric f...  2017
# 5979   Discovering Latent Network Structure in Point ...  2014
#
#                                                 keywords
# 39405  [mathematical, algorithmic, principal, geometr...
# 32474  [algorithm, piecewise, regression, continuous,...
# 21846  [algorithms, selection, functions, algorithm, ...
# 35372  [methodology, characterizations, different, de...
# 2618   [reinforcement, superhuman, performance, chall...
# ...                                                  ...
# 14053  [performance, heuristic, algorithms, parameter...
# 22957  [classifiers, available, examining, diversity,...
# 22533  [exploiting, processes, behaviour, procedure, ...
# 6836   [clustering, universal, approaches, understand...
# 5979   [relationships, difficult, impossible, interac...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 39405    [mathematical, algorithmic, principal, geometr...
# 32474    [algorithm, piecewise, regression, continuous,...
# 21846    [algorithms, selection, functions, algorithm, ...
# 35372    [methodology, characterizations, different, de...
# 2618     [reinforcement, superhuman, performance, chall...
#                                ...
# 22238    [techniques, analyzing, hyperspectral, particu...
# 11231    [literature, explaining, successful, classifie...
# 11530    [collaborative, filtering, information, regres...
# 35664    [theoretical, algorithm, literature, introduce...
# 3538     [framework, aggregated, wasserstein, computing...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8767 words.
# Out of those 4489 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="70dad3e6-a354-427d-828c-57718d51b489" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70dad3e6-a354-427d-828c-57718d51b489")) {                    Plotly.newPlot(                        "70dad3e6-a354-427d-828c-57718d51b489",                        [{"x":["different","mathematical","optimization","direction","identifies","composition","operators","computational","standpoint","associated","sufficient","geometric","principal","combination","multipliers","algorithmic","alternating","conditions","modification","repeatedly","estimation","demonstrate","comparing","algorithms","continuous","piecewise","empirically","incorporating","clustering","regression","performance","partition","likelihood","algorithm","parameters","effectiveness","discontinuous","reasonable","interesting","functions","probability","efficiency","restricted","theoretical","outperforms","consistent","conditional","iteration","constraint","dimension","regarding","previously","satisfied","selection","condition","recognition","properties","significantly","convexity","systematically","independent","cardinality","information","contributions","relations","asymmetry","semantics","declarative","understood","characterizations","stratified","systematic","methodology","situation","constructions","implications","applications","implement","arbitrary","configured","potentially","recurrent","important","introduce","challenging","structure","limitation","supervised","reinforcement","procedure","neuroscience","extending","prospects","challenge","superhuman","experiments","importantly","objective","modalities","classification","boltzmann","architecture","associate","hierarchical","inputoutput","unsupervised","handwritten","generates","associative","reconstruct","advantage","propagation","representation","correctly","representations","directional","extracting","techniques","signature","computationally","extraction","reasoning","generalises","ontologies","algorithmically","evaluation","practical","approximations","encouraging","computing","preserves","entailments","guaranteed","infeasible","denoising","classical","smoothness","corrupted","assumption","iterative","furthermore","spatially","inference","introduces","middlebury","stationary","solutions","improving","experimental","uncertainty","graphical","dependencies","typically","disparity","structured","inferring","complement","including","exploited","technique","scheduling","optimized","traveling","tournament","considered","distances","consisting","optimally","exploratory","partitions","programming","segmentation","prototype","distributed","functional","represents","prototypes","relevance","determine","differential","formalism","practically","parametric","underlying","capabilities","nonparametric","governing","conventional","observations","modelling","coefficients","knowledge","impossible","equations","estimated","interactions","formulated","introducing","processes","application"],"y":[743,58,306,67,13,30,61,306,3,110,68,79,27,129,12,36,30,131,34,10,219,546,69,575,117,13,72,47,160,118,888,31,54,842,225,210,5,33,72,233,180,164,50,155,259,81,99,32,76,57,46,82,10,167,45,367,206,265,11,22,126,8,686,55,114,4,99,17,26,8,3,39,62,25,7,31,428,77,81,5,42,130,395,316,277,328,17,196,125,97,7,22,2,165,2,595,26,160,38,520,15,249,10,99,4,150,25,53,8,25,96,79,358,31,218,14,66,386,11,89,131,126,1,26,3,259,135,28,20,118,25,2,43,13,29,116,16,17,62,84,173,20,215,98,6,16,145,111,386,85,59,50,87,14,119,21,17,249,20,253,25,46,9,1,136,28,43,14,5,13,119,191,30,107,41,43,2,33,60,28,23,13,45,125,53,21,0,101,82,44,34,359,15,27,62,64,24,30,98,243],"type":"bar"},{"x":["different","mathematical","optimization","direction","identifies","composition","operat ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4489,), (4489, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8075

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Continuous</span> <span style=''>Semantic</span> <span style=''>Topic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Embedding</span> <span style=''>Model</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Autoencoder</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>semantic</span> <span style=''>topic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>model</span> <span style=''>(CSTEM)</span> <span style=''>which</span> <span style=''>finds</span> <span style=''>latent</span> <span style=''>topic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>documents</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>semantic</span> <span style=''>distance</span> <span style=''>function</span> <span style=''>between</span> <span style=''>the</span> <span style=''>topics</span> <span style=''>and</span> <span style=''>the</span> <span style=''>words</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>autoencoder(VAE)</span> <span style=''>The</span> <span style=''>semantic</span> <span style=''>distance</span> <span style=''>could</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>by</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style=''>bell</span> <span style=''>shaped</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style=''>distance</span> <span style=''>function</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Euclidean</span> <span style=''>space</span> <span style=''>for</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Mahalanobis</span> <span style=''>distance</span> <span style=''>is</span> <span style=''>used</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>In</span> <span style=''>order</span> <span style=''>for</span> <span style=''>the</span> <span style=''>semantic</span> <span style=''>distance</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>more</span> <span style=''>properly</span> <span style=''>we</span> <span style=''>newly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>additional</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>for</span> <span style=''>each</span> <span style=''>word</span> <span style=''>to</span> <span style=''>take</span> <span style=''>out</span> <span style=''>the</span> <span style=''>global</span> <span style=''>factor</span> <span style=''>from</span> <span style=''>this</span> <span style=''>distance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>indicating</span> <span style=''>how</span> <span style=''>likely</span> <span style=''>it</span> <span style=''>occurs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regardless</span> <span style=''>of</span> <span style=''>its</span> <span style=''>topic</span> <span style=''>It</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>certainly</span> <span style=''>improves</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Subspace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Thresholding</span> <span style=''>and</span> <span style=''>Spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3345070422535211);'>dimensional</span> <span style=''>data</span> <span style=''>points</span> <span style=''>into</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3345070422535211);'>dimensional</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subspaces</span> <span style=''>The</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subspaces</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.31782945736434104);'>dimensions</span> <span style=''>and</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615384);'>orientations</span> <span style=''>are</span> <span style=''>unknown</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>and</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>thresholding</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style=''>the</span> <span style=''>data</span> <span style=''>points</span> <span style=''>followed</span> <span style=''>by</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>analysis</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>succeeds</span> <span style=''>even</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subspaces</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intersect</span> <span style=''>and</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.31782945736434104);'>dimensions</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subspaces</span> <span style=''>scale</span> <span style=''>(up</span> <span style=''>to</span> <span style=''>a</span> <span style=''>log</span> <span style=''>factor)</span> <span style=''>linearly</span> <span style=''>in</span> <span style=''>the</span> <span style=''>ambient</span> <span style='background-color:rgba(255, 0, 0, 0.3999999999999999);'>dimension</span> <span style=''>Moreover</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>also</span> <span style=''>succeeds</span> <span style=''>for</span> <span style=''>data</span> <span style=''>points< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multivariate</span> <span style=''>Non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style=''>Time</span> <span style=''>Series</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Automatic</span> <span style=''>DBMS</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Diagnosis</span> <br/><br/><span style=''>Anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>in</span> <span style=''>database</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>management</span> <span style=''>systems</span> <span style=''>(DBMSs)</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>because</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>(stat)</span> <span style=''>and</span> <span style=''>event</span> <span style=''>metrics</span> <span style=''>in</span> <span style=''>big</span> <span style=''>data</span> <span style=''>system</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>I</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style=''>DBMS</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diagnosis</span> <span style=''>system</span> <span style=''>that</span> <span style=''>detects</span> <span style=''>anomaly</span> <span style=''>periods</span> <span style=''>with</span> <span style=''>abnormal</span> <span style=''>DB</span> <span style=''>stat</span> <span style=''>metrics</span> <span style=''>and</span> <span style=''>finds</span> <span style=''>causal</span> <span style=''>events</span> <span style=''>in</span> <span style=''>the</span> <span style=''>periods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reconstruction</span> <span style=''>error</span> <span style=''>from</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoder</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>process</span> <span style=''>control</span> <span style=''>approach</span> <span style=''>are</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>time</span> <span style=''>period</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>anomalies</span> <span style=''>Related</span> <span style=''>events</span> <span style=''>are</span> <span style=''>found</span> <span style=''>using</span> <span style=''>time</span> <span style=''>series</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>measures</span> <span style=''>between</span> <span style=''>events</span> <span style=''>and</span> <span style=''>abnormal</span> <span style=''>stat</span> <span style=''>metrics</span> <span style=''>After</span> <span style=''>training</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoder</span> <span style=''>with</span> <span style=''>DBMS</span> <span style=''>metric</span> <span style=''>data</span> <span style=''>efficacy</span> <span style=''>of</span> <span style=''>anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigated</span> <span style=''>from</span> <span style=''>other</span> <span style=''>DBMSs</span> <span style='background-color: ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.0775831247765463)
# 	segmentation (0.06828745084018592)
# 	experimental (0.13800500536288882)
# 	information (0.2452627815516625)
# 	architecture (0.08902395423668216)
# 	representation (0.12799427958526993)
# 	detection (0.1269217018233822)
# 	different (0.2656417590275295)
# 	recognition (0.13121201287093315)
# 	convolutional (0.13442974615659636)
#
# Some Statistics words are:
# 	algorithm (0.3889166250624064)
# 	estimation (0.16874687968047927)
# 	variables (0.1382925611582626)
# 	stochastic (0.13929106340489267)
# 	theoretical (0.15376934598102845)
# 	statistical (0.15327009485771342)
# 	distribution (0.18871692461308037)
# 	dimensional (0.1892161757363954)
# 	inference (0.2076884672990514)
# 	regression (0.18072890664003993)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="20f68ef1-e5bb-45fa-9db3-4d572889e67a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20f68ef1-e5bb-45fa-9db3-4d572889e67a")) {                    Plotly.newPlot(                        "20f68ef1-e5bb-45fa-9db3-4d572889e67a",                        [{"x":["different","mathematical","optimization","direction","identifies","composition","operators","computational","standpoint","associated","sufficient","geometric","principal","combination","multipliers","algorithmic","alternating","conditions","modification","repeatedly","estimation","demonstrate","comparing","algorithms","continuous","piecewise","empirically","incorporating","clustering","regression","performance","partition","likelihood","algorithm","parameters","effectiveness","discontinuous","reasonable","interesting","functions","probability","efficiency","restricted","theoretical","outperforms","consistent","conditional","iteration","constraint","dimension","regarding","previously","satisfied","selection","condition","recognition","properties","significantly","convexity","systematically","independent","cardinality","information","contributions","relations","asymmetry","semantics","declarative","understood","characterizations","stratified","systematic","methodology","situation","constructions","implications","applications","implement","arbitrary","configured","potentially","recurrent","important","introduce","challenging","structure","limitation","supervised","reinforcement","procedure","neuroscience","extending","prospects","challenge","superhuman","experiments","importantly","objective","modalities","classification","boltzmann","architecture","associate","hierarchical","inputoutput","unsupervised","handwritten","generates","associative","reconstruct","advantage","propagation","representation","correctly","representations","directional","extracting","techniques","signature","computationally","extraction","reasoning","generalises","ontologies","algorithmically","evaluation","practical","approximations","encouraging","computing","preserves","entailments","guaranteed","infeasible","denoising","classical","smoothness","corrupted","assumption","iterative","furthermore","spatially","inference","introduces","middlebury","stationary","solutions","improving","experimental","uncertainty","graphical","dependencies","typically","disparity","structured","inferring","complement","including","exploited","technique","scheduling","optimized","traveling","tournament","considered","distances","consisting","optimally","exploratory","partitions","programming","segmentation","prototype","distributed","functional","represents","prototypes","relevance","determine","differential","formalism","practically","parametric","underlying","capabilities","nonparametric","governing","conventional","observations","modelling","coefficients","knowledge","impossible","equations","estimated","interactions","formulated","introducing","processes","application","automatic","faithfulness","monolingual","translation","components","combinations","bilingual","describes","artificial","submitted","integrated","submission","approximation","exponential","variationally","discussed","dependency","extension","approximating","marginals","decomposed","requirement","constrained","distributions","distribution","requiring","derivation","canonical","variational","tractable","iteratively","intractable","generalized","approximate","convergence","derivations","argumentation","researched","automated","philosophy","difficult","variables","inconsistencies","framework","resulting","comparison","possibility","classifiers","otherwise","sequential","intrinsic","dimensional","comparisons","obtaining","construction","candidate","evalua ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	governing
# 	seemingly
# 	explodingvanishing
# 	tibshirani
# 	ergodicity
# 	promotion
# 	asymmetries
# 	bivariate
# 	parametrizations
# 	semiparametric
# 	preconditioned
# 	distributionally
# 	stragglers
# 	equiangular
# 	straggler
# 	multiplayer
# 	multiarmed
# 	robustification
# 	ellipsoid
# 	confounding
# Some words which never appear in Statistics papers:
# 	superhuman
# 	inputoutput
# 	ontologies
# 	entailments
# 	middlebury
# 	traveling
# 	monolingual
# 	bilingual
# 	argumentation
# 	generalisable
# 	illumination
# 	monocular
# 	reproduced
# 	plasmodium
# 	underwater
# 	executions
# 	memorizing
# 	succeeding
# 	depicting
# 	vibration

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.080809636772544e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7758333333333334
